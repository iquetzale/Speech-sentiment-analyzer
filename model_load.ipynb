# %%
# !pip install ffmpeg-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ffmpeg-python in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python) (0.18.3)

# %%
from keras.models import model_from_json
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
import pandas as pd
import librosa
import numpy as np
import os

# Define the function to extract MFCC features
def extract_features(audio, sr):
    # Compute MFCC features
    mfcc = librosa.feature.mfcc(y=audio, sr=sr)
    # Flatten the MFCC matrix
    mfcc_flat = mfcc.flatten()
    # Return the flattened MFCC features
    return mfcc_flat

# Define the function to load and preprocess audio files
def preprocess_audio(audio_path):
    # Load audio file
    audio, sr = librosa.load(audio_path, sr=None)
    # Normalize the audio using librosa
    max_amp = np.max(np.abs(audio))
    normalized_x = audio / max_amp

    # Trim the audio
    xt, index = librosa.effects.trim(normalized_x, top_db=30)

    # Pad the audio if necessary
    final_x = np.pad(xt, (0, 320000 - len(xt)), 'constant')

    # Perform feature extraction using MFCCs
    features = extract_features(final_x, sr)

    return features

# %%
def reverse(onehot):
  return np.argmax(onehot, axis=None, out=None)

# %%
labels = {0: 'negative', 1: 'neutral', 2: 'positive'}

# %%
from IPython.display import Audio, display

# %%
def predict(audio_path):
  features = preprocess_audio(audio_path)
  features = np.expand_dims(features, axis=0)
  predictions = loaded_model.predict(features)
  print(display(Audio(audio_path)))
  return labels.get(reverse(predictions))

# %%
predict('example.wav')
# transcript: 'Congratulations: you won the challenge'
# Out:
# 1/1 [==============================] - 0s 183ms/step
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# None
# 'positive'

# %%
predict('example2.wav')
# transcript: 'You should try to help more'
# Out:
# 1/1 [==============================] - 0s 35ms/step
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# None
# 'neutral'

# %%
predict('example3.wav')
# transcript: 'Please try to improve your attitude'
# Out:
# 1/1 [==============================] - 0s 68ms/step
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# None
# 'neutral'
